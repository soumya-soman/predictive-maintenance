# %%
import pandas as pd
from plotly.subplots import make_subplots
import plotly.express as px
import plotly.graph_objs as go
import plotly.io as pio
from matplotlib.pyplot import figure

# %% [markdown]
# # Failure data analysis

# %%
failures_url="https://raw.githubusercontent.com/soumya-soman/predictive-maintenance/master/PdM_failures.csv"
 
failures_kaggle = pd.read_csv(failures_url)
failures_kaggle.head()
# Out:
#               datetime  machineID failure
# 0  2015-01-05 06:00:00          1   comp4
# 1  2015-03-06 06:00:00          1   comp1
# 2  2015-04-20 06:00:00          1   comp2
# 3  2015-06-19 06:00:00          1   comp4
# 4  2015-09-02 06:00:00          1   comp4

# %%
failures_mocked=pd.read_csv('/home/ccs/Notebooks/Predictive_Maintanence/failures_mock_test.csv',sep = '\t')
 
# failures = pd.read_csv(failures_url)
failures_mocked.head()
# Out:
#               datetime  machineID failure
# 0  2015-01-02 06:00:00         95  comp14
# 1  2015-01-02 06:00:00         81  comp12
# 2  2015-01-02 06:00:00         79  comp11
# 3  2015-01-02 06:00:00          3   comp4
# 4  2015-01-02 06:00:00         80  comp24

# %% [markdown]
# # component

# %%
pd.value_counts(failures_mocked['failure']).plot.barh(figsize=(10, 5))

# %%
pd.value_counts(failures_kaggle['failure']).plot.barh(figsize=(10, 5))

# %% [markdown]
# # machineID

# %%
pd.value_counts(failures_mocked['machineID']).plot.bar(figsize=(30, 10))

# %%
pd.value_counts(failures_kaggle['machineID']).plot.bar(figsize=(30,10))

# %% [markdown]
# # datetime

# %%
pd.value_counts(failures_mocked['datetime']).plot.bar(figsize=(55, 10))

# %%
pd.value_counts(failures_kaggle['datetime']).plot.bar(figsize=(55, 10))

# %% [markdown]
# # Maintanence data analysis

# %%
maint_url="https://raw.githubusercontent.com/soumya-soman/predictive-maintenance/master/PdM_maint.csv"
 
maint_kaggle = pd.read_csv(maint_url)
maint_kaggle.head()
# Out:
#               datetime  machineID   comp
# 0  2014-06-01 06:00:00          1  comp2
# 1  2014-07-16 06:00:00          1  comp4
# 2  2014-07-31 06:00:00          1  comp3
# 3  2014-12-13 06:00:00          1  comp1
# 4  2015-01-05 06:00:00          1  comp4

# %%
maint_mocked=pd.read_csv('/home/ccs/Notebooks/Predictive_Maintanence/maint_mock_test.csv',sep=',')
 
# maint = pd.read_csv(maint_url)
maint_mocked.head()
# Out:
#               datetime  machineID    comp
# 0  2015-01-02 06:00:00         93  comp17
# 1  2015-01-02 06:00:00         69  comp15
# 2  2015-01-02 06:00:00         88  comp14
# 3  2015-01-02 06:00:00         26  comp21
# 4  2015-01-02 06:00:00         33  comp23

# %% [markdown]
# # component

# %%
pd.value_counts(maint_mocked['comp']).plot.barh(figsize=(10, 5))

# %%
pd.value_counts(maint_kaggle['comp']).plot.barh(figsize=(10, 5))

# %% [markdown]
# # machineID

# %%
pd.value_counts(maint_mocked['machineID']).plot.bar(figsize=(30, 5))

# %%
pd.value_counts(maint_kaggle['machineID']).plot.bar(figsize=(30, 5))

# %% [markdown]
# # datetime

# %%
pd.value_counts(maint_mocked['datetime']).plot.bar(figsize=(55, 5))

# %%
pd.value_counts(maint_kaggle['datetime']).plot.bar(figsize=(55, 5))
