# %%
import numpy as np
import pandas as pd

# %%
failures_url="https://raw.githubusercontent.com/soumya-soman/predictive-maintenance/master/PdM_failures.csv"
 
failures = pd.read_csv(failures_url)
failures.head()
failures.rename(columns={'failure':'comp'}, inplace=True)

# %%
failures.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 761 entries, 0 to 760
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   datetime   761 non-null    datetime64[ns]
#  1   machineID  761 non-null    int64
#  2   comp       761 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 18.0+ KB

# %%
failures['datetime'] = pd.to_datetime(failures['datetime'])
failures.head()
# Out:
#              datetime  machineID   comp m-date
# 0 2015-01-05 06:00:00          1  comp4  01-05
# 1 2015-03-06 06:00:00          1  comp1  03-06
# 2 2015-04-20 06:00:00          1  comp2  04-20
# 3 2015-06-19 06:00:00          1  comp4  06-19
# 4 2015-09-02 06:00:00          1  comp4  09-02

# %%
pd.set_option('display.max_rows', 5000)
failures['m-date'] = failures['datetime'].dt.strftime('%m-%d')
failures = failures.sort_values(by='m-date')
failures['m-date'].head(761)
# Out:
# 409    01-02
# 583    01-02
# 739    01-02
# 595    01-02
# 430    01-02
# 94     01-02
# 95     01-02
# 422    01-02
# 107    01-02
# 578    01-02
# 523    01-02
# 631    01-02
# 627    01-02
# 331    01-02
# 161    01-02
# 568    01-02
# 188    01-02
# 256    01-02
# 690    01-02
# 373    01-02
# 524    01-02
# 137    01-04
# 296    01-04
# 271    01-04
# 176    01-05
# 609    01-05
# 461    01-05
# 493    01-05
# 0      01-05
# 257    01-06
# 64     01-07
# 11     01-07
# 541    01-07
# 65     01-07
# 691    01-08
# 222    01-09
# 22     01-09
# 212    01-10
# 234    01-10
# 508    01-11
# 350    01-11
# 446    01-13
# 130    01-13
# 410    01-14
# 616    01-15
# 396    01-15
# 596    01-16
# 108    01-16
# 480    01-16
# 16     01-17
# 96     01-17
# 584    01-17
# 285    01-17
# 740    01-18
# 550    01-18
# 384    01-19
# 53     01-19
# 383    01-19
# 640    01-19
# 138    01-19
# 177    01-20
# 87     01-20
# 88     01-20
# 657    01-20
# 462    01-20
# 494    01-20
# ...

# %%
failure
1,3,12,27
feb 11,13,26,28,
mar 8,10,26,30,
apr 12,23,25,28,
may 12,14,25,26,27,29
jun 7,8,9,10,11,12,28,
jul 7,9,11,13,24,26,28
12,22,23,26,27

7,9,11,24,25,27

7,9,,11,16,22,26

5,8,21,22,23,

6,8,10,18,21,
remove fe rows after this elimination

# %%
maint_url="https://raw.githubusercontent.com/soumya-soman/predictive-maintenance/master/PdM_maint.csv"
 
maint = pd.read_csv(maint_url)
maint.head(5)
# Out:
#               datetime  machineID   comp
# 0  2014-06-01 06:00:00          1  comp2
# 1  2014-07-16 06:00:00          1  comp4
# 2  2014-07-31 06:00:00          1  comp3
# 3  2014-12-13 06:00:00          1  comp1
# 4  2015-01-05 06:00:00          1  comp4

# %%
maint.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3286 entries, 0 to 3285
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   datetime   3286 non-null   object
#  1   machineID  3286 non-null   int64
#  2   comp       3286 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 77.1+ KB

# %%
maint['datetime'] = pd.to_datetime(maint['datetime'])
pd.set_option('display.max_rows', 5000)
maint['m-date'] = maint['datetime'].dt.strftime('%m-%d')
maint = failures.sort_values(by='m-date')
maint['m-date'].head(761)
# Out:
# 409    01-02
# 373    01-02
# 690    01-02
# 256    01-02
# 188    01-02
# 568    01-02
# 161    01-02
# 331    01-02
# 627    01-02
# 631    01-02
# 523    01-02
# 578    01-02
# 107    01-02
# 422    01-02
# 95     01-02
# 94     01-02
# 430    01-02
# 595    01-02
# 739    01-02
# 583    01-02
# 524    01-02
# 296    01-04
# 271    01-04
# 137    01-04
# 176    01-05
# 609    01-05
# 461    01-05
# 493    01-05
# 0      01-05
# 257    01-06
# 65     01-07
# 64     01-07
# 11     01-07
# 541    01-07
# 691    01-08
# 222    01-09
# 22     01-09
# 212    01-10
# 234    01-10
# 508    01-11
# 350    01-11
# 446    01-13
# 130    01-13
# 410    01-14
# 396    01-15
# 616    01-15
# 480    01-16
# 596    01-16
# 108    01-16
# 16     01-17
# 96     01-17
# 584    01-17
# 285    01-17
# 740    01-18
# 550    01-18
# 640    01-19
# 383    01-19
# 138    01-19
# 384    01-19
# 53     01-19
# 177    01-20
# 87     01-20
# 88     01-20
# 657    01-20
# 462    01-20
# 494    01-20
# ...

# %%
jan 1 3 12 27 29 
feb 11 13 26 
mar 8 10 26 30 
12 23 25 28
12 14 25 26 27 29
7-9 11 12 28 
7 9 11 1324 26 28
12 22 23 26 27 
7 9 11 2425 27
7 9 11 1216 22 26
5 8 21 22 23 
6 8 10 18 21 28

# %%
common = maint.merge(failures, on=['datetime', 'machineID', 'comp'])
common
# Out:
#                 datetime  machineID   comp
# 0    2015-01-05 06:00:00          1  comp4
# 1    2015-03-06 06:00:00          1  comp1
# 2    2015-04-20 06:00:00          1  comp2
# 3    2015-06-19 06:00:00          1  comp4
# 4    2015-09-02 06:00:00          1  comp4
# ..                   ...        ...    ...
# 738  2015-11-29 06:00:00         99  comp3
# 739  2015-12-14 06:00:00         99  comp4
# 740  2015-02-12 06:00:00        100  comp1
# 741  2015-09-10 06:00:00        100  comp1
# 742  2015-12-09 06:00:00        100  comp2
#
# [743 rows x 3 columns]

# %%
import seaborn as sns

sns.pairplot(maint)

# %%
sns.pairplot(failures,hue = 'comp')

# %%
failures.groupby(['datetime','machineID','comp'])['comp'].count().head(35)
# Out:
# datetime             machineID  comp
# 2015-01-02 03:00:00  16         comp1    1
#                                 comp3    1
#                      17         comp4    1
#                      22         comp1    1
#                      35         comp1    1
#                      45         comp1    1
#                      51         comp1    1
#                      56         comp3    1
#                      58         comp2    1
#                      59         comp1    1
#                      73         comp2    1
#                      79         comp1    1
#                      80         comp2    1
#                      83         comp4    1
#                      86         comp1    1
#                      87         comp1    1
#                      94         comp4    1
#                      99         comp3    1
# 2015-01-02 06:00:00  24         comp1    1
#                      73         comp3    1
#                      81         comp1    1
# ...

# %%
maint.groupby(['datetime','machineID','comp'])['comp'].count().head(35)
# Out:
# datetime             machineID  comp
# 2014-06-01 06:00:00  1          comp2    1
#                      6          comp2    1
#                      9          comp1    1
#                                 comp2    1
#                      11         comp2    1
#                      16         comp4    1
#                      18         comp3    1
#                      19         comp4    1
#                      20         comp1    1
#                                 comp2    1
#                      21         comp3    1
#                      26         comp2    1
#                      37         comp2    1
#                      39         comp1    1
#                      40         comp2    1
#                      41         comp2    1
#                      47         comp4    1
#                      48         comp3    1
#                      52         comp2    1
#                      54         comp3    1
#                      56         comp4    1
# ...
